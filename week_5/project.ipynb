# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

employees = {
    "Oluwatamilore": {"department": "Logistics", "other_members": []},
    "Ayomide": {"department": "Accounting", "other_members": []},
    "Oshim": {"department": "Delivery", "other_members": []},
    "Chukwunonye": {"department": "Accounting", "other_members": []},
    "Chiemeziem": {"department": "Logistics", "other_members": []},
    "Oluwatimehin": {"department": "Accounting", "other_members": []},
    "Osose": {"department": "Logistics", "other_members": []},
    "Daniel": {"department": "Delivery", "other_members": []},
    "Onyekachi": {"department": "Delivery", "other_members": []},
    "Shalom": {"department": "Delivery", "other_members": []},
    "Nedi": {"department": "Logistics", "other_members": []},
    "Stephanie": {"department": "Accounting", "other_members": []},
    "Jason": {"department": "Administration", "other_members": []},
    "Edward": {"department": "Delivery", "other_members": []},
    "Otu": {"department": "Administration", "other_members": []},
    "Onyinyechi": {"department": "Administration", "other_members": []},
    "Makuochukwu": {"department": "Logistics", "other_members": []},
    "Moyosore": {"department": "Logistics", "other_members": []},
    "Ayonete": {"department": "Accounting", "other_members": []},
    "Eche": {"department": "Accounting", "other_members": []},
    "Michael": {"department": "Delivery", "other_members": []},
    "Oluwadamilola": {"department": "Delivery", "other_members": []},
    "Chijindu": {"department": "Logistics", "other_members": []},
    "Joseph": {"department": "Logistics", "other_members": []},
    "Daisy": {"department": "Accounting", "other_members": []},
    "Samuel": {"department": "Accounting", "other_members": []},
    "Betha": {"department": "Accounting", "other_members": []},
    "Boluwatife": {"department": "Delivery", "other_members": []},
    "Mary": {"department": "Delivery", "other_members": []},
    "Raphael": {"department": "Administration", "other_members": []},
    "Victor": {"department": "Administration", "other_members": []},
    "Derek": {"department": "Logistics", "other_members": []},
    "Akorede": {"department": "Accounting", "other_members": []},
    "Rasheed": {"department": "Accounting", "other_members": []},
    "Daniel": {"department": "Accounting", "other_members": []},
    "Mary-Cynthia": {"department": "Logistics", "other_members": []},
    "Owoede": {"department": "Logistics", "other_members": []},
    "Oluwafikunmi": {"department": "Delivery", "other_members": []},
    "Uchenna": {"department": "Delivery", "other_members": []},
    "Ejike": {"department": "Administration", "other_members": []}
}

for name, info in employees.items():
    department = info["department"]
    other_members = [emp_name for emp_name, emp_info in employees.items() if emp_info["department"] == department and emp_name != name]
    employees[name]["other_members"] = other_members

def check_employee(name, department):
    if name in employees and employees[name]["department"] == department:
        return True, employees[name]["other_members"]
    else:
        return False, None




def submit():
 name = name_entry.get()
 department = department_entry.get()
 exists, other_members = check_employee(name, department)
 if exists:
   message = f"Welcome, {name}!\nOther members of the {department} department: {', '.join(other_members)}"
   messagebox.showinfo("Employee Found", message)
 else:
   messagebox.showinfo("Employee Not Found", f"No employee named {name} in the {department} department.")


# Create main window
root = tk. Tk()
root.title("Login Form")
root. geometry("1080x720")

# Create username Label and entry
name_label = tk.Label(root, text="Please input the first name of the employee:")
name_label.pack()
name_entry = tk. Entry(root)
name_entry.pack()

# Create password Label and entry
department_label = tk.Label(root, text="Please input the department of the employee:")
department_label.pack()
department_entry = tk. Entry(root)
department_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event Loop
root.mainloop()
